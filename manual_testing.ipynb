# %%
from circle import Circle
from rectangle import Rectangle


# created two circles and printed their areas
c= Circle(x=0, y=0, radius=1)
c2= Circle(x=1, y=1, radius=2)
print(c.area)
print(c2.area)
# Out:
# 3.141592653589793
# 12.566370614359172

# %%
#test comparison
c > c2
# Out:
# False

# %%
# change radius and test comparison again
c.radius = 2
c2.radius = 1
c > c2
# Out:
# True

# %%
# created two circles and printed their areas
c= Circle(x=0, y=0, radius=1)
c2= Circle(x=1, y=1, radius=2)
print(c)
print(c2)
# Out:
# Circle with center (0, 0) and radius1
# Circle with center (1, 1) and radius2

# %%
c2= Circle(x=1, y=1, radius=2)
print(c2)
# Out:
# Circle with center (1, 1) and radius2

# %%
# chatgpt suggested tests code
try:
    c.translate("hello", 5)
except TypeError as e:
    print("Caught error:", e)
# Out:
# Caught error: dx and dy must be numbers

# %%
# test if circle is a unit circle
print(c.is_unit_circle())
# Out:
# True

# %%
# test translation
c.translate(0, 0)
c2.translate(1, 1)
print(c)
print(c2)
# Out:
# Circle with center (0, 0) and radius1
# Circle with center (2, 2) and radius2

# %% [markdown]
# ## Rectangle

# %%
r1 = Rectangle(x=0, y=0, width=4, height=2)
r2 = Rectangle(x=1, y=1, width=4, height=4)
print(r1)
print(r2)
# Out:
# Rectangle with center (0, 0), width 4, height 2
# Rectangle with center (1, 1), width 3, height 3

# %%
r1.height = "five"
print(r1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 r1.height = "five"
#       2 print(r1)
#
# File ~/lab_2_geometry/Lab_2_geometry/rectangle.py:33, in Rectangle.height(self, value)
#      30 @height.setter
#      31 def height(self, value):
#      32     if not isinstance(value, (int, float)):
# ---> 33         raise TypeError("height must be a number")
#      34     if value <= 0:
#      35         raise ValueError("height must be greater than 0")
#
# TypeError: height must be a number

# %%
r1.width = -2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 r1.width = -2
#
# File ~/lab_2_geometry/Lab_2_geometry/rectangle.py:22, in Rectangle.width(self, value)
#      20     raise TypeError("width must be a number")
#      21 if value <= 0:
# ---> 22     raise ValueError("width must be greater than 0")
#      23 self._width = value
#
# ValueError: width must be greater than 0

# %%
print(r1.area)
print(r1.perimeter)
print(r2.area)
print(r2.perimeter)
# Out:
# 8
# 12
# 9
# 12

# %%
r1.translate(5, -2)

# %%
try:
    rectangle2 = Rectangle(x=0, y=0, width=3, height="5")
except TypeError as e:
    print("Caught TypeError (rectangle constructor):", e)
# Out:
# Caught TypeError (rectangle constructor): width and height must be numbers

# %%
r1 == c2
# Out:
# False

# %%
print (r2.is_square())
# Out:
# True
